# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5324.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3382.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1398.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1142.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5002.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2646.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3476.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1613.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5593.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2975.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4841.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4962.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5244.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5534.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4930.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2140.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3129.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5387.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2069.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3893.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3573.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3654.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5598.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_490.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4941.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5888.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5219.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_838.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1073.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3622.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5618.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2006.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1024.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_891.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_243.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5561.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5321.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2546.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3157.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2125.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5777.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5497.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5096.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3982.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1327.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1311.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1439.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1206.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1901.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4345.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4275.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4087.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4600.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_253.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5158.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4854.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5992.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4051.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2669.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_609.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2421.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4901.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_417.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2762.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_54.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_266.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_456.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3905.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4685.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_175.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1661.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_769.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4794.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3420.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_745.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5510.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1423.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5722.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2052.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1137.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2478.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4463.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1124.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2925.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1783.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_670.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5062.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1916.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3975.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4225.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1066.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1171.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5524.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4756.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1983.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1836.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2886.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3197.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1103.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_94.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1097.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4842.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4316.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4917.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3310.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5262.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_248.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3282.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4513.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2381.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3928.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_620.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5029.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5427.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3057.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3908.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3902.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5842.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3491.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_317.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1970.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_353.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2382.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3976.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4378.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4886.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4064.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5001.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2571.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3063.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4470.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_780.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5712.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1056.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3804.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5563.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_398.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3981.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5604.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1228.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1524.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_318.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5399.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4746.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_559.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5360.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4104.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3374.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4447.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2569.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_226.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4759.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2277.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2563.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4652.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5153.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_80.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4708.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2325.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3517.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2457.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1845.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4098.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3327.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1772.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4072.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5577.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4004.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4276.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2739.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5807.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3312.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3304.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2560.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_766.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1102.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1950.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_889.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4246.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_529.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_31.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_314.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1170.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4259.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_840.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1936.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2993.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3820.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1600.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4342.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1219.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3417.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4253.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_95.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3554.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2160.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4380.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4032.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5693.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2117.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4102.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3080.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4331.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5890.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5248.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_293.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2443.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_575.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_867.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5049.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3182.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_819.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2410.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4037.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2969.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5726.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1494.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3480.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1147.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1831.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5020.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4362.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2532.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5449.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_168.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5637.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_657.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4797.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1571.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5990.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4711.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2564.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4952.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1064.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5522.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2055.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4373.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3954.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2113.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2728.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1660.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3766.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3929.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2025.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_240.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_484.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3935.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5055.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4421.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_656.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1706.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2207.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2082.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3645.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5835.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5764.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5125.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2487.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1220.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1760.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5290.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2898.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3074.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2539.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_123.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2255.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5483.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4397.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_294.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4724.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_8.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2433.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3380.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4033.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4572.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_944.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_180.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2547.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5299.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_105.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4182.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5698.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4893.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4153.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5060.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3760.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2201.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5699.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1739.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2066.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2590.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1374.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3541.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1229.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5438.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1422.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_984.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4089.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_969.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_801.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_139.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5956.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_449.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1788.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3837.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5319.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4422.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1300.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1710.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3543.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4130.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5460.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3740.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1444.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1550.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2830.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1949.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1478.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4029.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1867.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_907.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5432.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2260.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5484.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5887.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1331.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5231.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_179.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5703.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3748.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_81.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4975.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5685.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_384.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2649.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4837.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2989.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_852.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5292.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_901.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1577.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3713.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_467.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2682.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5803.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3204.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2589.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1855.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3266.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4178.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3601.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2499.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4524.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1417.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3818.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4152.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1676.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3538.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5011.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_916.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2736.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3617.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5692.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2348.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1711.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4204.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4428.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3724.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_903.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5271.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2168.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_943.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3494.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_876.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3008.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2432.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_210.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1561.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_110.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_895.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2869.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4200.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2036.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1076.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4480.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4931.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4258.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_434.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5507.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3007.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4663.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2119.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2899.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3388.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_341.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_382.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1176.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3268.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2581.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5172.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4850.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5139.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5033.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1753.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4113.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5639.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3977.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2558.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1754.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4520.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_487.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2907.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2664.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3824.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3597.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_866.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2958.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2293.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1632.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_219.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4063.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3738.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2795.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2485.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4838.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3426.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1677.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2825.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4879.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5760.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3721.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_701.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_630.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_332.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_899.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5503.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_224.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_49.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2584.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2814.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_597.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_556.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3769.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4704.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5750.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1245.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5950.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4143.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3192.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2509.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2345.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5502.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4092.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1735.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_853.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4911.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2890.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5513.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5608.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_820.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4875.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3383.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5180.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5716.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_258.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1773.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_887.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_725.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4202.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5895.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4660.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_478.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2567.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5804.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1158.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4508.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3188.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2583.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5974.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3294.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4984.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2823.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3796.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_330.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1168.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4198.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_3306.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1098.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_1003.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2016.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_718.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_277.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5834.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_648.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4817.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_5954.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_2085.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4728.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_441.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_4735.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB-/cluster_5_281.BMP
# ...
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3221.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2178.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5420.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1993.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_482.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3422.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4733.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_51.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1563.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_951.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2372.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1612.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4965.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1154.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5335.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3558.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2680.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2889.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4218.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3594.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4863.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2505.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1878.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4623.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5742.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2585.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3505.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1193.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_628.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5327.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2804.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5404.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_359.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1521.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_879.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4283.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5667.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4409.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4761.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5106.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_930.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_268.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4374.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4176.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5273.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1810.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3887.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2619.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5508.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3907.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4701.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1431.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1254.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_213.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_27.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_650.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5504.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5212.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1464.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4823.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2181.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3220.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2193.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5820.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3375.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2614.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5512.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4169.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3864.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3031.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2856.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1723.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2686.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_787.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2726.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3626.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5183.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4240.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_338.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4687.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_472.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2446.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5110.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1801.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_700.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2488.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4119.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2675.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1686.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2607.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5905.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2796.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_882.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5193.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3250.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5549.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3707.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_929.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2530.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4052.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3580.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_996.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3884.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_703.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_663.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_687.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1276.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3857.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4951.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3302.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5971.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5411.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5031.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2314.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5861.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1226.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_462.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3924.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3190.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5844.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4557.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4622.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5045.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4001.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3313.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3018.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_76.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1615.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1071.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5620.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5988.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2818.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2911.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5640.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_474.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2195.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1179.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1277.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2234.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2458.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_515.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4762.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3669.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3747.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3107.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3725.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5854.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3045.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2822.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5697.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3176.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4566.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2536.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_495.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2850.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_361.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1467.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4790.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_3168.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2436.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1030.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_2965.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_1480.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4537.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_4220.BMP
# /kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/AB+/cluster_4_5145.BMP

# %%
import os
import torch
import torchvision
import tarfile
from torch.utils.data import random_split
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Compose, Resize
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
transform = Compose([
    Resize((128, 128)),  # Resize all images to 128x128
    ToTensor()          # Convert images to tensors
])
dataset = ImageFolder('/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group', transform=transform)

# %%
print(dataset.classes)
# Out:
# ['A+', 'A-', 'AB+', 'AB-', 'B+', 'B-', 'O+', 'O-']

# %%
img, label = dataset[0]
print(img.shape, label)
plt.imshow(img.permute(1, 2, 0))
# Out:
# torch.Size([3, 128, 128]) 0

# %% [markdown]
# # Training , Testing and Validiation Dataset

# %%
random_seed=42
torch.manual_seed(random_seed)

# %%
val_size = 1000
test_size = 1000
train_size = len(dataset) - val_size - test_size

train_ds, val_ds, test_ds = random_split(dataset, [train_size, val_size, test_size])
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (4000, 1000, 1000)

# %%
from torch.utils.data.dataloader import DataLoader

batch_size = 32

# %%
train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=4, pin_memory=True)
val_dl = DataLoader(val_ds, batch_size*2, num_workers=4, pin_memory=True) # We can double the batch size

# %%
from torchvision.utils import make_grid

def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(12, 6))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(images, nrow=16).permute(1, 2, 0))
        break

# %%
show_batch(train_dl)

# %%
for images, labels in train_dl:
    print('images shape:', images.shape)
    break
# Out:
# images shape: torch.Size([32, 3, 128, 128])

# %% [markdown]
# # Model Building

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss

    def validation_step(self, batch):
        images, labels = batch
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}

    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}

    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))

# %%
def conv_block(in_channels, out_channels, pool=False):
    layers = [nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
              nn.BatchNorm2d(out_channels),
              nn.ReLU(inplace=True)]
    if pool:
        layers.append(nn.MaxPool2d(2))
    return nn.Sequential(*layers)

class ResNet9(ImageClassificationBase):
    def __init__(self, in_channels, num_classes):
        super().__init__()
        self.conv1 = conv_block(in_channels, 64) #64 x 32x 32
        self.conv2 = conv_block(64, 128, pool=True) # 128 x 16 x 16
        self.res1 = nn.Sequential(conv_block(128, 128), # 128 x 16 x 16
                                  conv_block(128, 128)) # 128 x 16 x 16

        self.conv3 = conv_block(128, 256, pool=True) # 256 x 8 x 8
        self.conv4 = conv_block(256,512, pool=True) # 512 x 4 x 4
        self.res2 = nn.Sequential(conv_block(512, 512), # 512 x 4 x 4
                                  conv_block(512, 512))# 512 x 4 x 4

        self.classifier = nn.Sequential(nn.AdaptiveMaxPool2d(1), # 512 x 1 x 1
                                        nn.Flatten(), # 512
                                        nn.Dropout(0.2),
                                        nn.Linear(512, num_classes)) # 10

    def forward(self, xb):
        out = self.conv1(xb)
        out = self.conv2(out)
        out = self.res1(out) + out
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.res2(out) + out
        out = self.classifier(out)
        return out

# %%
def get_default_device():
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

# %%
def to_device(data, device):
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

# %%
class DeviceDataLoader():
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device

    def __iter__(self):
        for b in self.dl:
            yield to_device(b, self.device)

    def __len__(self):
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(val_dl, device)
model = to_device(ResNet9(3, 8), device)
model
# Out:
# ResNet9(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res1): Sequential(
#     (0): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): AdaptiveMaxPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=512, out_features=8, bias=True)
#   )
# )

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit_one_cycle(epochs, max_lr, model, train_loader, val_loader,
                  weight_decay=0, grad_clip=None, opt_func=torch.optim.SGD):
    torch.cuda.empty_cache()
    history = []

    # Set up cutom optimizer with weight decay
    optimizer = opt_func(model.parameters(), max_lr, weight_decay=weight_decay)
    # Set up one-cycle learning rate scheduler
    sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=epochs,
                                                steps_per_epoch=len(train_loader))

    for epoch in range(epochs):
        # Training Phase
        model.train()
        train_losses = []
        lrs = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()

            # Gradient clipping
            if grad_clip:
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)

            optimizer.step()
            optimizer.zero_grad()

            # Record & update learning rate
            lrs.append(get_lr(optimizer))
            sched.step()

        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        result['lrs'] = lrs
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
evaluate(model, val_dl)
# Out:
# {'val_loss': 2.0810251235961914, 'val_acc': 0.11328125}

# %%
epochs = 20
max_lr = 0.01
grad_clip = 0.1
weight_decay = 1e-4
opt_func = torch.optim.Adam
history = []

# %%
# %%time
history += fit_one_cycle(epochs, max_lr, model, train_dl, val_dl,
                             grad_clip=grad_clip,
                             weight_decay=weight_decay,
                             opt_func=opt_func)
# Out:
# Epoch [0], last_lr: 0.00103, train_loss: 1.6083, val_loss: 1.3022, val_acc: 0.5320
# Epoch [1], last_lr: 0.00279, train_loss: 1.0888, val_loss: 1.5555, val_acc: 0.5625
# Epoch [2], last_lr: 0.00519, train_loss: 1.1171, val_loss: 2.4932, val_acc: 0.4875
# Epoch [3], last_lr: 0.00759, train_loss: 1.2245, val_loss: 1.8496, val_acc: 0.5473
# Epoch [4], last_lr: 0.00936, train_loss: 1.2060, val_loss: 1.0487, val_acc: 0.6852
# Epoch [5], last_lr: 0.01000, train_loss: 0.9731, val_loss: 1.7042, val_acc: 0.5826
# Epoch [6], last_lr: 0.00987, train_loss: 0.7643, val_loss: 0.9053, val_acc: 0.6891
# Epoch [8], last_lr: 0.00891, train_loss: 0.5825, val_loss: 2.2192, val_acc: 0.5977
# Epoch [9], last_lr: 0.00812, train_loss: 0.5173, val_loss: 1.2878, val_acc: 0.6344
# Epoch [10], last_lr: 0.00717, train_loss: 0.4523, val_loss: 0.4342, val_acc: 0.8314
# Epoch [11], last_lr: 0.00611, train_loss: 0.4240, val_loss: 0.7989, val_acc: 0.7330
# Epoch [12], last_lr: 0.00500, train_loss: 0.3613, val_loss: 0.4340, val_acc: 0.8197
# Epoch [13], last_lr: 0.00389, train_loss: 0.3515, val_loss: 0.5727, val_acc: 0.7578
# Epoch [14], last_lr: 0.00283, train_loss: 0.2902, val_loss: 0.4795, val_acc: 0.8256
# Epoch [15], last_lr: 0.00188, train_loss: 0.2290, val_loss: 0.3322, val_acc: 0.8639
# Epoch [16], last_lr: 0.00109, train_loss: 0.1892, val_loss: 0.2323, val_acc: 0.9029
# Epoch [17], last_lr: 0.00050, train_loss: 0.1483, val_loss: 0.2242, val_acc: 0.9104
# Epoch [18], last_lr: 0.00013, train_loss: 0.1163, val_loss: 0.2126, val_acc: 0.9078
# Epoch [19], last_lr: 0.00000, train_loss: 0.1066, val_loss: 0.2085, val_acc: 0.9107
# CPU times: user 5min 33s, sys: 4min 44s, total: 10min 17s
# Wall time: 10min 10s

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');

# %%
plot_accuracies(history)

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');

# %%
plot_losses(history)

# %%
def plot_lrs(history):
    lrs = np.concatenate([x.get('lrs', []) for x in history])
    plt.plot(lrs)
    plt.xlabel('Batch no.')
    plt.ylabel('Learning rate')
    plt.title('Learning Rate vs. Batch no.');

# %%
plot_lrs(history)

# %%
test_loader = DeviceDataLoader(DataLoader(test_ds, batch_size*2), device)
result = evaluate(model, test_loader)
result
# Out:
# {'val_loss': 0.20593297481536865, 'val_acc': 0.920703113079071}

# %%
from sklearn.metrics import classification_report

# %%
@torch.no_grad()
def evaluate_with_predictions(model, val_loader):
    model.eval()
    predictions, targets = [], []
    for batch in val_loader:
        images, labels = batch
        outputs = model(images)
        _, preds = torch.max(outputs, dim=1)
        predictions.extend(preds.cpu().numpy())
        targets.extend(labels.cpu().numpy())
    return np.array(predictions), np.array(targets)

# %% [markdown]
# # Evaluation

# %%
predictions, targets = evaluate_with_predictions(model, test_loader)
print("\nClassification Report:\n")
print(classification_report(targets, predictions, target_names=dataset.classes))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#           A+       0.94      0.92      0.93        95
#           A-       0.88      0.96      0.92       158
#          AB+       0.94      0.88      0.91       128
#          AB-       0.96      0.91      0.94       138
#           B+       0.96      0.94      0.95       115
#           B-       0.93      0.97      0.95       113
#           O+       0.85      0.87      0.86       132
#           O-       0.92      0.90      0.91       121
#
#     accuracy                           0.92      1000
#    macro avg       0.92      0.92      0.92      1000
# weighted avg       0.92      0.92      0.92      1000

# %%
def visualize_predictions(model, val_loader, num_images=6):
    model.eval()
    images, labels = next(iter(val_loader))
    images, labels = images[:num_images], labels[:num_images]
    outputs = model(images)
    _, preds = torch.max(outputs, dim=1)

    fig, axes = plt.subplots(1, num_images, figsize=(15, 6))
    for i, ax in enumerate(axes):
        ax.imshow(images[i].permute(1, 2, 0).cpu())
        ax.set_title(f"Actual: {dataset.classes[labels[i]]}\nPredicted: {dataset.classes[preds[i]]}")
        ax.axis('off')
    plt.tight_layout()
    plt.show()

# %%
visualize_predictions(model, test_loader)

# %%
def predict_image(img, model):
    # Convert to a batch of 1
    xb = to_device(img.unsqueeze(0), device)
    # Get predictions from model
    yb = model(xb)
    # Pick index with highest probability
    _, preds  = torch.max(yb, dim=1)
    # Retrieve the class label
    return dataset.classes[preds[0].item()]

# %%
img, label = test_ds[179]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Label: A- , Predicted: A-

# %%
torch.save(model.state_dict(), 'FingurePrintTOBloodGroup.pth')

# %%
from PIL import Image
img = Image.open('/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/B+/cluster_2_10.BMP')
plt.imshow(img)

# %%
import torchvision.transforms as tt

# %%
transform = Compose([
    Resize((128, 128)),# Adjust the crop as per your needs
    tt.RandomHorizontalFlip(),
    ToTensor()# Convert the image to a tensor
])

# Apply the transformations to the image
img_tensor = transform(img)

# %%
plt.imshow(img_tensor.permute(1, 2, 0))

# %%
img_tensor.shape
# Out:
# torch.Size([4, 128, 128])

# %%
# Keep only first 3 channels (RGB)
# if img_tensor.shape[0] == 4:
#     img_tensor = img_tensor[:3, :, :]   # shape -> [3, 128, 128]

# # Add batch dimension
# img_tensor = img_tensor.unsqueeze(0)    # shape -> [1, 3, 128, 128]

# %%
img_tensor.shape
# Out:
# torch.Size([4, 128, 128])

# %%
res = predict_image(img_tensor, model)
res
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 res = predict_image(img_tensor, model)
#       2 res
#
# Cell In[37], line 5, in predict_image(img, model)
#       3 xb = to_device(img.unsqueeze(0), device)
#       4 # Get predictions from model
# ----> 5 yb = model(xb)
#       6 # Pick index with highest probability
#       7 _, preds  = torch.max(yb, dim=1)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[15], line 28, in ResNet9.forward(self, xb)
#      27 def forward(self, xb):
# ---> 28     out = self.conv1(xb)
#      29     out = self.conv2(out)
#      30     out = self.res1(out) + out
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:458, in Conv2d.forward(self, input)
#     457 def forward(self, input: Tensor) -> Tensor:
# --> 458     return self._conv_forward(input, self.weight, self.bias)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:454, in Conv2d._conv_forward(self, input, weight, bias)
#     450 if self.padding_mode != 'zeros':
#     451     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     452                     weight, bias, self.stride,
#     453                     _pair(0), self.dilation, self.groups)
# --> 454 return F.conv2d(input, weight, bias, self.stride,
#     455                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Given groups=1, weight of size [64, 3, 3, 3], expected input[1, 4, 128, 128] to have 3 channels, but got 4 channels instead

# %% [markdown]
# # Deployment

# %%
code = """
import torch
from torchvision import models
import streamlit as st
from PIL import Image
from torchvision import transforms as tt

# Define the transformation as done in your code
transform = tt.Compose([
    tt.Resize((128, 128)),
    tt.RandomHorizontalFlip(),
    tt.ToTensor()  # Convert the image to a tensor
])

# Load the trained model (on CPU)
model = models.resnet18(pretrained=False)  # Make sure to load your own model architecture
model.load_state_dict(torch.load('FingurePrintTOBloodGroup.pth'))
model.eval()  # Set the model to evaluation mode

# Load the dataset or class names (update this with your actual dataset)
class_names = ['Class1', 'Class2', 'Class3']  # Replace with actual classes

# Function to predict the image class
def predict_image(img, model):
    # Apply transformations
    img_tensor = transform(img)
    img_tensor = img_tensor.unsqueeze(0)  # Add batch dimension

    # Get predictions from the model
    with torch.no_grad():
        yb = model(img_tensor)
        _, preds = torch.max(yb, dim=1)

    # Return the class label
    return class_names[preds[0].item()]

# Streamlit user interface
st.title("Fingerprint to Blood Group Prediction")
st.write("Upload a fingerprint image to predict the blood group.")

# File uploader for image input
uploaded_file = st.file_uploader("Choose an image...", type="jpg")

if uploaded_file is not None:
    # Open the image file
    img = Image.open(uploaded_file)
    
    # Display the image in the app
    st.image(img, caption='Uploaded Image', use_column_width=True)

    # Call the predict function
    prediction = predict_image(img, model)
    
    # Display prediction result
    st.write(f"Predicted Blood Group: {prediction}")
"""

with open('app.py', 'w') as f:
    f.write(code)

# %%
# !pip freeze > requirements.txt

# %%
# !python --version
# Out:
# Python 3.10.14

# %%
# !pip install torch torchvision streamlit

# %%
# !streamlit run app.py & npx localtunnel --port 8501
